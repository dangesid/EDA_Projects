# %%
# !pip install plotly

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.preprocessing import LabelEncoder

# %%
df = pd.read_csv(r"datasets/Data Developer Salary/Dataset salary 2024.csv")

df = pd.DataFrame(df)
df.head()
# Out:
#    work_year experience_level employment_type                  job_title  \
# 0       2024               SE              FT                AI Engineer
# 1       2024               SE              FT                AI Engineer
# 2       2024               SE              FT              Data Engineer
# 3       2024               SE              FT              Data Engineer
# 4       2024               SE              FT  Machine Learning Engineer
#
#    salary salary_currency  salary_in_usd employee_residence  remote_ratio  \
# 0  202730             USD         202730                 US             0
# 1   92118             USD          92118                 US             0
# 2  130500             USD         130500                 US             0
# 3   96000             USD          96000                 US             0
# 4  190000             USD         190000                 US             0
#
#   company_location company_size
# 0               US            M
# ...

# %%
df.columns
# Out:
# Index(['work_year', 'experience_level', 'employment_type', 'job_title',
#        'salary', 'salary_currency', 'salary_in_usd', 'employee_residence',
#        'remote_ratio', 'company_location', 'company_size'],
#       dtype='object')

# %%
df.duplicated().sum()
# Out:
# 6421

# %%
df = df.drop_duplicates()

# %%
import plotly.express as px

columns = ['work_year', 'experience_level', 'employment_type', 'job_title',
       'salary', 'salary_currency', 'salary_in_usd', 'employee_residence',
       'remote_ratio', 'company_location', 'company_size']

for column in columns:
  fig = px.histogram(data_frame = df,x = column)

  fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
label_encoder = LabelEncoder()

df["experience_level"] = label_encoder.fit_transform(df["experience_level"])
df["employment_type"] = label_encoder.fit_transform(df["employment_type"])
df["job_title"] = label_encoder.fit_transform(df["job_title"])
df["salary_currency"] = label_encoder.fit_transform(df["salary_currency"])
df["employee_residence"] = label_encoder.fit_transform(df["employee_residence"])
df["company_location"] = label_encoder.fit_transform(df["company_location"])
df["company_size"] = label_encoder.fit_transform(df["company_size"])

# %%
df.head()
# Out:
#    work_year  experience_level  employment_type  job_title  salary  \
# 0       2024                 3                2          2  202730
# 1       2024                 3                2          2   92118
# 2       2024                 3                2         57  130500
# 3       2024                 3                2         57   96000
# 4       2024                 3                2        120  190000
#
#    salary_currency  salary_in_usd  employee_residence  remote_ratio  \
# 0               21         202730                  84             0
# 1               21          92118                  84             0
# 2               21         130500                  84             0
# 3               21          96000                  84             0
# 4               21         190000                  84             0
#
#    company_location  company_size
# 0                74             1
# 1                74             1
# 2                74             1
# ...

# %%
df
# Out:
#        work_year experience_level employment_type                  job_title  \
# 0           2024               SE              FT                AI Engineer
# 1           2024               SE              FT                AI Engineer
# 2           2024               SE              FT              Data Engineer
# 3           2024               SE              FT              Data Engineer
# 4           2024               SE              FT  Machine Learning Engineer
# ...          ...              ...             ...                        ...
# 16529       2020               SE              FT             Data Scientist
# 16530       2021               MI              FT   Principal Data Scientist
# 16531       2020               EN              FT             Data Scientist
# 16532       2020               EN              CT      Business Data Analyst
# 16533       2021               SE              FT       Data Science Manager
#
# ...

# %%
import seaborn as sns

# %%
plt.figure(figsize=(10,6))
sns.histplot(df["work_year"],bins=20,kde=True, color='green')
plt.title("Distribution of Work Years")
plt.xlabel("Work Years")
plt.ylabel("Freequency")
plt.show()

# %%
plt.figure(figsize=(10,6))
sns.barplot(x="work_year",y="salary",data = df, palette='pastel')

plt.title("Work Year vs Salary")
plt.xlabel("Work Years")
plt.ylabel("Salary")
plt.show()
# Out:
# <ipython-input-100-456f8765f2f1>:2: FutureWarning:
#
#
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.

# %%
plt.figure(figsize=(10, 6))
sns.boxplot(x='company_size', y='salary', data=df, palette='muted')
plt.title('Salary Distribution by Company Size')
plt.xlabel('Company Size')
plt.ylabel('Salary')
plt.show()
# Out:
# <ipython-input-101-0a6eacbb1671>:2: FutureWarning:
#
#
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.

# %%
# plot the graph between experience level and salary in usd
df = df.head(1000)
plt.figure(figsize=(10,6))

plt.plot(df['experience_level'],df['salary_in_usd'],marker='o', linestyle='-')

plt.xlabel('experience_level')
plt.ylabel('salary_in_usd')
plt.title("Experience Vs Salary Graphs")
# Out:
# Text(0.5, 1.0, 'Experience Vs Salary Graphs')
